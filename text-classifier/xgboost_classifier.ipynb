# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
import sklearn.metrics as metrics
import numpy as np
from xgboost import XGBClassifier
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline
from xgboost import cv
import xgboost as xgb

# %%
df = pd.read_csv("/users/edfarber/scratch/dataset/multimodalpulmonaryembolismdataset/merged_pe_data.csv")

# %%
df = df.drop("pe_type", axis=1)

# %%
train_df = df.loc[df["split"] == "train"]

# %%
val_df = df.loc[df["split"] == "val"]
test_df = df.loc[df["split"] == "test"]

# %%
x_train = train_df.drop(["idx", "label", "split"], axis=1).to_numpy()

# %%
y_train = train_df["label"].to_numpy()

# %%
scaler = StandardScaler()

# %%
x_train = scaler.fit_transform(x_train)

# %%
model = LogisticRegression(random_state=42, solver="liblinear", penalty="l1", max_iter=150, C=0.055)

# %%
model.fit(x_train, y_train)
# Out:
# LogisticRegression(C=0.055, max_iter=150, penalty='l1', random_state=42,
#                    solver='liblinear')

# %%
scores = cross_val_score(model, x_train, y_train, cv=5, scoring='roc_auc')
print(f"CV AUC = {scores.mean():.3f} ± {scores.std():.3f}")
# Out:
# CV AUC = 0.925 ± 0.015

# %%
x_val = val_df.drop(["idx", "label", "split"], axis=1).to_numpy()
x_val = scaler.transform(x_val)

# %%
y_val = val_df["label"].to_numpy()

# %%
y_prob = model.predict_proba(x_val)[:, 1]

# %%
print(f"Validation AUROC: {metrics.roc_auc_score(y_val, y_prob):.3f}")
# Out:
# Validation AUROC: 0.910

# %%
model = XGBClassifier(
    n_estimators=100,
    max_depth=5,
    learning_rate=0.1,
    random_state=123,
    eval_metric='auc',
    early_stopping_rounds=10,
    alpha=10,
    objective="binary:logistic",
    colsample_bytree=0.3
)

# %%
model.fit(x_train, y_train, eval_set=[(x_val, y_val)], verbose=True)
# Out:
# [0]	validation_0-auc:0.72778
# [1]	validation_0-auc:0.88785
# [2]	validation_0-auc:0.88535
# [3]	validation_0-auc:0.89434
# [4]	validation_0-auc:0.88377
# [5]	validation_0-auc:0.88126
# [6]	validation_0-auc:0.88519
# [7]	validation_0-auc:0.89003
# [8]	validation_0-auc:0.89412
# [9]	validation_0-auc:0.89586
# [10]	validation_0-auc:0.89336
# [11]	validation_0-auc:0.89281
# [12]	validation_0-auc:0.89259
# [13]	validation_0-auc:0.89357
# [14]	validation_0-auc:0.89444
# [15]	validation_0-auc:0.89336
# [16]	validation_0-auc:0.89455
# [17]	validation_0-auc:0.89673
# [18]	validation_0-auc:0.89630
# [19]	validation_0-auc:0.89804
# [20]	validation_0-auc:0.89657
# [21]	validation_0-auc:0.89809
# [22]	validation_0-auc:0.89668
# [23]	validation_0-auc:0.89853
# [24]	validation_0-auc:0.89858
# [25]	validation_0-auc:0.89880
# [26]	validation_0-auc:0.89815
# [27]	validation_0-auc:0.89858
# [28]	validation_0-auc:0.89880
# [29]	validation_0-auc:0.89815
# [30]	validation_0-auc:0.89739
# [31]	validation_0-auc:0.89924
# [32]	validation_0-auc:0.89826
# [33]	validation_0-auc:0.89804
# [34]	validation_0-auc:0.89913
# [35]	validation_0-auc:0.90044
# [36]	validation_0-auc:0.90261
# [37]	validation_0-auc:0.90316
# [38]	validation_0-auc:0.90458
# [39]	validation_0-auc:0.90577
# [40]	validation_0-auc:0.90632
# [41]	validation_0-auc:0.90686
# [42]	validation_0-auc:0.90686
# [43]	validation_0-auc:0.90719
# [44]	validation_0-auc:0.90839
# [45]	validation_0-auc:0.90664
# [46]	validation_0-auc:0.90795
# [47]	validation_0-auc:0.90817
# [48]	validation_0-auc:0.90828
# [49]	validation_0-auc:0.90893
# [50]	validation_0-auc:0.91100
# [51]	validation_0-auc:0.91133
# [52]	validation_0-auc:0.91133
# [53]	validation_0-auc:0.91122
# [54]	validation_0-auc:0.91068
# [55]	validation_0-auc:0.91046
# [56]	validation_0-auc:0.91220
# [57]	validation_0-auc:0.91220
# [58]	validation_0-auc:0.91220
# [59]	validation_0-auc:0.91242
# [60]	validation_0-auc:0.91209
# [61]	validation_0-auc:0.91176
# [62]	validation_0-auc:0.91187
# [63]	validation_0-auc:0.91220
# [64]	validation_0-auc:0.91275
# [65]	validation_0-auc:0.91318
# [66]	validation_0-auc:0.91416
# [67]	validation_0-auc:0.91351
# [68]	validation_0-auc:0.91405
# [69]	validation_0-auc:0.91460
# [70]	validation_0-auc:0.91580
# [71]	validation_0-auc:0.91558
# [72]	validation_0-auc:0.91580
# [73]	validation_0-auc:0.91590
# [74]	validation_0-auc:0.91590
# [75]	validation_0-auc:0.91612
# [76]	validation_0-auc:0.91688
# [77]	validation_0-auc:0.91645
# [78]	validation_0-auc:0.91590
# [79]	validation_0-auc:0.91558
# [80]	validation_0-auc:0.91558
# [81]	validation_0-auc:0.91580
# [82]	validation_0-auc:0.91612
# [83]	validation_0-auc:0.91580
# [84]	validation_0-auc:0.91623
# [85]	validation_0-auc:0.91645
# [86]	validation_0-auc:0.91612
# XGBClassifier(alpha=10, base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.3, device=None, early_stopping_rounds=10,
#               enable_categorical=False, eval_metric='auc', feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=0.1, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, ...)

# %%
x_test = scaler.transform(test_df.drop(["idx", "label", "split"], axis=1).to_numpy())
y_test = test_df["label"].to_numpy()
y_prob = model.predict_proba(x_test)[:, 1]
print(f"Test AUROC: {metrics.roc_auc_score(y_test, y_prob):.3f}")
# Out:
# Test AUROC: 0.939

# %%
y_prob_val = model.predict_proba(x_val)[:, 1]

# %%
print(f"Test AUROC: {metrics.roc_auc_score(y_val, y_prob_val):.3f}")
# Out:
# Test AUROC: 0.917

# %%
test_df = df.loc[df["split"] == "test"]
exported_df = test_df[["idx", "label"]].copy()
exported_df["text_preds"] = y_prob_test
exported_df.to_csv("./test_proba_xgb.csv", index=False)

# %%
val_df = df.loc[df["split"] == "val"]
exported_val = val_df[["idx", "label"]].copy()
exported_val["text_preds"] = y_prob_val
exported_val.to_csv("./validation_proba_xgb.csv", index=False)
